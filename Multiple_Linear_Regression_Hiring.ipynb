# %%
import pandas as pd
import numbers as np
from sklearn import linear_model

# %%
df = pd.read_csv("E:\Girish Documents\Study\Data Science\DataScience_ML_Study\ML_Study_LinearRegression\Multiple_Linear_Regression_Hiring.csv")

# %%
df.head(15)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# %pip install word2number
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached word2number-1.1.zip (9.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5589 sha256=df8dcedffc1956c5093944d92b939473cd9cc1798c5493cc5010f6e798323230
#   Stored in directory: c:\users\sawoo\appdata\local\pip\cache\wheels\cd\ef\ae\073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.experience = df.experience.fillna('zero')

# %%
df.head(15)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
from word2number import w2n

# %%
df['experience'] = df['experience'].apply(lambda x: w2n.word_to_num(x))

# %%
df.head(15)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)	']], df['salary($)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)	']], df['salary($)'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df['Test_score'] = df['test_score(out of 10)']
df['Interview_score'] = df['interview_score(out of 10)']
df['Salary'] = df['salary($)']

# %%
df.head(15)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000
#
#    Test_score  Interview_score  Salary
# 0         8.0                9   50000
# 1         8.0                6   45000
# 2         6.0                7   60000
# 3        10.0               10   65000
# 4         9.0                6   70000
# 5         7.0               10   62000
# ...

# %%
df.drop(columns=['test_score(out of 10)','interview_score(out of 10)','salary($)'],inplace=True)

# %%
df.head(15)
# Out:
#    experience  Test_score  Interview_score  Salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         NaN                7   72000
# 7          11         7.0                8   80000

# %%
import math

df_test_score_median = math.floor(df.Test_score.median())
print(df_test_score_median)
# Out:
# 8

# %%
df.Test_score = df.Test_score.fillna(df_test_score_median)

# %%
df.head(15)
# Out:
#    experience  Test_score  Interview_score  Salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['experience','Test_score','Interview_score']], df.Salary)
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\sawoo\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
m = reg.coef_
m
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
c = reg.intercept_
c
# Out:
# 17737.263464337688

# %%
#y = m1*x + m2*x + m3*x

y = m[0] * 2 + m[1] * 9 + m[2] * 6 + c
y
# Out:
# 53205.96797671033
